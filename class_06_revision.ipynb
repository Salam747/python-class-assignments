# %% [markdown]
# <a href="https://colab.research.google.com/github/Salam747/python-class-assignments/blob/main/class_06_revision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import Tuple
from typing_extensions import TypeVarTuple
# list

months : list = ["January","February","March","April","May","June","July","August","September"]

months[0] = "Mohram"
print(months)

# slicing list
print(months[0:7])

print(months[3:6])

print(months[4:])

# nagative slicing
print(months[-3:-1])



# Tupples
numbers:tuple = (11,22,33,44,55,66,77,88,99)
# numbers[0] = 554  / Error
print(numbers)

print(numbers[-4:-1])
print(numbers[0:2])


# tupples

frinds: Tuple[str] = ("Salam","Qasim","Dawood")
print(frinds)
print(type(frinds))


# tuple to list conversion
tuple_to_list = list(frinds)
print(tuple_to_list)
print(type(tuple_to_list))


# Adding element to list
print(tuple_to_list.append("Khuwaja"))
print(tuple_to_list)

# # Converting the list back to tuple
list_to_tuple = tuple(tuple_to_list)
print(list_to_tuple)
print(type(list_to_tuple))




# Dictionary

student_info = {
    "name" : "Abdul Salam",
    "rollNumber" : 50333,
    "courses" : ["Python","Open AI","FastAPI","Docker"],
    "Assignmnets": {
        "AssigmnetOne": "Completed",
        "AssigmnetTwo": "Not Completed",

    }
    }

print(student_info)
print(student_info["courses"][2])
print(student_info["courses"][-1])

print(student_info ["Assignmnets"]["AssigmnetTwo"])
print(student_info ["Assignmnets"]["AssigmnetOne"])




for xyz in student_info.values():
  print(xyz)

  for keys, values in student_info.items():
    print(keys,values)


for i in range(100,130):
  print(i)




try:
  req = request.get("https://jsonplaceholder.typicode.com/posts")
  print(req.json())

except Exception as e:
    print(e)

    print("Error agya hai ..")

else:
  print("yaha tak pohnch gaya ...")



try:
    url = requests.get('https://jsonplaceholder.typicode.com/posts')
    res = url.json()
    print(res)
except Exception as e:
  print(e)

finally:
  print("Request ended ... ")
# Out:
# ['Mohram', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September']
# ['Mohram', 'February', 'March', 'April', 'May', 'June', 'July']
# ['April', 'May', 'June']
# ['May', 'June', 'July', 'August', 'September']
# ['July', 'August']
# (11, 22, 33, 44, 55, 66, 77, 88, 99)
# (66, 77, 88)
# (11, 22)
# ('Salam', 'Qasim', 'Dawood')
# <class 'tuple'>
# ['Salam', 'Qasim', 'Dawood']
# <class 'list'>
# None
# ['Salam', 'Qasim', 'Dawood', 'Khuwaja']
# ('Salam', 'Qasim', 'Dawood', 'Khuwaja')
# <class 'tuple'>
# {'name': 'Abdul Salam', 'rollNumber': 50333, 'courses': ['Python', 'Open AI', 'FastAPI', 'Docker'], 'Assignmnets': {'AssigmnetOne': 'Completed', 'AssigmnetTwo': 'Not Completed'}}
# FastAPI
# Docker
# Not Completed
# Completed
# Abdul Salam
# name Abdul Salam
# rollNumber 50333
# courses ['Python', 'Open AI', 'FastAPI', 'Docker']
# Assignmnets {'AssigmnetOne': 'Completed', 'AssigmnetTwo': 'Not Completed'}
# 50333
# name Abdul Salam
# rollNumber 50333
# ...
