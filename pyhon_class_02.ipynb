# %% [markdown]
# <a href="https://colab.research.google.com/github/Salam747/python-class-assignments/blob/main/pyhon_class_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tupples

# %%
names = ("Abdul Salam","Muhamad Umar",22211)
print(names)
# Out:
# ('Abdul Salam', 'Muhamad Umar', 22211)

# %% [markdown]
# get value in tupples

# %%
names = ("Abdul Salam","Muhammad Umar",2211)
print(names[0])
print(names[1])
print(names[2])
# Out:
# Abdul Salam
# Muhammad Umar
# 2211
# ('Abdul Salam', 'Muhammad Umar', 2211)

# %%
names1 = ("Riyaz","Saeed","Nawaz")

names1 = ["Manzoor",[1]]

print(names1)
# Out:
# ['Manzoor', [1]]

# %% [markdown]
# in Tupples use f string

# %%
names = ("Abdul Salam","Muhammad Umar",2211)
print(f"my name is ",{names[1]})
# Out:
# my name is  {'Muhammad Umar'}

# %% [markdown]
# tupples methode couunt and index

# %%
id_card = ("Abdul Salam","Muhammad Umar",2211,25541)
print(id_card.count("abdul salam"))
print(id_card.index(2211))
# Out:
# 0
# 2

# %% [markdown]
# Dictionary in Python

# %%
id_card ={
    "name" :"Abdul Salam",
    "fName": "Muhammad Umar",
    "cnic": 233,
    "dof": 332,
}

print(id_card)
# Out:
# {'name': 'Abdul Salam', 'fName': 'Muhammad Umar', 'cnic': 233, 'dof': 332}

# %% [markdown]
# nested dictionray

# %%
result ={
    "Abdul Salam":{
        "Subjec": "Math",
        "Subject":"Eng",
        "Subject":"Isl",
        "Score": 250
    }
}

print(result["Abdul Salam"]["Subject"])
# Out:
# Isl
