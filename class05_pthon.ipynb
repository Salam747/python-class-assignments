# %% [markdown]
# <a href="https://colab.research.google.com/github/Salam747/python-class-assignments/blob/main/class05_pthon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  try:
    result = 10 / 0
  except ZeroDivisionError:
    print("Error: Division By Zero ")
  except  Exception as e:
    print(f"An unexpected error occurred: {e}")

  else:
    print(f"Result: {result}")

  finally:
    print("This always executes ")
# Out:
# Error: Division By Zero
# This always executes

# %%
  name: str = "Abdul Salam"
  phon_num: int = 340888888
  age:float = 23.44
  color:list = ["white","Black","Blue"]
  color2:list = ["white","black", 22]

  fruits_name: set  = {"apple","banana","orange","mango","strawberry"}

  print(fruits_name)
  # print(fruits_name[0]) # print(fruits_name[0]) # Error
# Out:
# {'mango', 'banana', 'orange', 'strawberry', 'apple'}

# %%
# union
electronic_cust: set = {"salam","qaim","Dawood"}
garmnets_cust: set = {"Haroon","salam","Mohsin"}

merge = electronic_cust.union(garmnets_cust)
print(merge)
# Out:
# {'Haroon', 'qaim', 'Dawood', 'salam', 'Mohsin'}

# %%
# Reacts
wow_react: set = {"salam","Ali","Qasim"}
lough_react: set = {"Noman","Muhammad"}
heart_react: set = {"Haroon","Uzair"}

all = wow_react | lough_react | heart_react
print(all)
# Out:
# {'Haroon', 'Qasim', 'Noman', 'Muhammad', 'Ali', 'Uzair', 'salam'}

# %%
# Intersection (common elements)

summer_fruits: set = {"mango","banana","watermelon"}
winter_fruites: set = {"orange","grapse","kivi"}

commen_fruites = summer_fruits.intersection(winter_fruites)
print(commen_fruites)


winter_fruits: set = {"apple","banana","mango"}
winter_fruits: set = {'oranges' , 'apple' , 'annar'}

commen_fruites = winter_fruits.intersection(winter_fruits)
print(commen_fruites)




winter_fruites: set ={"orange","apple","annar"}
if "orange" in winter_fruites:
    print("orange is  here")

if "mango" not in winter_fruites:
    winter_fruits.add("apple")


lunch = {"biryani"}
if "biryani" in lunch:
  lunch.discard("biryani")
# Out:
# set()
# {'apple', 'oranges', 'annar'}
# orange is  here

# %%
# For Loops (when you know the ending point)
# The following example is add to cart feature.
# Think yourself as a superstore customer.
# After shopping you will be charged the amount of the products you have purchased.
# Price of each product is added to the total


cart: list =[
    {"product": "Shirt", "Price": 55},
    {"product": "T Shirt" ,"Price": 35},
    {"product": "Shoes", "Price": 85},
    {"product": "socks", "Price": 15},
]

total: int = 0
for cash in cart:
    total = total + cash["Price"]
print(total)
# Out:
# 190

# %%
# While loop (executed till the certain condition is True)
# Think of yourself as a men who is doing the activity of scanning the price of the Product
# The duty of the men is to scan the price of all the products in the basket.
# When the items in the basket ends the condition becomes false and the program ends

total = 0

while True:
  price_input: str = input("Enter the price ")

  if price_input == "done":
    break

  if price_input.isdigit():
    total += int(price_input)
    print("Current total: ", total)
# Out:
# Enter the price 33
# Current total:  33
# Enter the price done
